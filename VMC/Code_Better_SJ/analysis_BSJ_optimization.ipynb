# %%
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np
df = pd.read_csv('helium.csv')
data = df.to_numpy()
E_exact = -2.903724377034119598311159245194404
min_index = np.argmin(data[:,8])
#Let us extract our columns
alpha = data[:,0]
beta = data[:,1]
w_ep = data[:,2]
w_ee = data[:,3]
f_ep = data[:,4]
f_ee = data[:,5]
acceptance = data[:,6]
E = data[:,7]
E_errbar = data[:,8]
w_bf = data[:,9]
f_bf = data[:,10]

#Parameters
alpha_min = alpha[min_index]
beta_min = beta[min_index]
w_ep_min = w_ep[min_index]
w_ee_min = w_ee[min_index]

# %%
print('Emin at:',E[min_index], 'Var:', E_errbar[min_index])
print('With parameters, a=',alpha[min_index],', b=',beta[min_index],', wep=',w_ep[min_index], 'wee=', w_ee_min, ', fep=',f_ep[min_index], 'fee=', f_ee[min_index],
      'wbf=', w_bf[min_index], ', fbf=',f_bf[min_index],)
print('Acceptance:', acceptance[min_index])
# Out:
# Emin at: -2.8934893035621445 Var: 0.0001478268713547
# With parameters, a= 1.96 , b= 0.0 , wep= 2.56 wee= 1.35 , fep= 0.77 fee= 0.41 wbf= 0.1 , fbf= 0.2875
# Acceptance: 0.69024475

# %%
df
# Out:
#     alpha  beta  w_ep  w_ee  f_ep  f_ee  acceptance         E  E_errbar  \
# 0    1.96     0  2.56  1.35  0.77  0.41    0.689721 -2.892578  0.000151
# 1    1.96     0  2.56  1.35  0.77  0.41    0.690245 -2.893489  0.000148
# 2    1.96     0  2.56  1.35  0.77  0.41    0.690097 -2.892541  0.000167
# 3    1.96     0  2.56  1.35  0.77  0.41    0.690382 -2.893021  0.000189
# 4    1.96     0  2.56  1.35  0.77  0.41    0.689949 -2.893483  0.000222
# 5    1.96     0  2.56  1.35  0.77  0.41    0.689922 -2.892133  0.000148
# 6    1.96     0  2.56  1.35  0.77  0.41    0.690180 -2.894293  0.000166
# 7    1.96     0  2.56  1.35  0.77  0.41    0.689874 -2.894055  0.000207
# 8    1.96     0  2.56  1.35  0.77  0.41    0.689905 -2.894870  0.000259
# 9    1.96     0  2.56  1.35  0.77  0.41    0.689795 -2.893207  0.000321
# 10   1.96     0  2.56  1.35  0.77  0.41    0.690073 -2.893169  0.000150
# 11   1.96     0  2.56  1.35  0.77  0.41    0.690877 -2.894409  0.000183
# 12   1.96     0  2.56  1.35  0.77  0.41    0.690880 -2.892439  0.000267
# 13   1.96     0  2.56  1.35  0.77  0.41    0.690469 -2.891990  0.000283
# 14   1.96     0  2.56  1.35  0.77  0.41    0.690269 -2.884934  0.000351
# 15   1.96     0  2.56  1.35  0.77  0.41    0.690097 -2.893031  0.000159
# 16   1.96     0  2.56  1.35  0.77  0.41    0.691616 -2.891219  0.000214
# 17   1.96     0  2.56  1.35  0.77  0.41    0.692174 -2.885947  0.000310
# 18   1.96     0  2.56  1.35  0.77  0.41    0.692088 -2.877201  0.000390
# 19   1.96     0  2.56  1.35  0.77  0.41    0.691362 -2.868462  0.000381
# 20   1.96     0  2.56  1.35  0.77  0.41    0.690642 -2.892165  0.000161
# 21   1.96     0  2.56  1.35  0.77  0.41    0.692968 -2.887744  0.000243
# 22   1.96     0  2.56  1.35  0.77  0.41    0.694462 -2.877625  0.000303
# 23   1.96     0  2.56  1.35  0.77  0.41    0.694459 -2.861913  0.000415
# 24   1.96     0  2.56  1.35  0.77  0.41    0.694212 -2.843743  0.000474
#
#      w_bf    f_bf
# 0   0.100  0.0500
# 1   0.100  0.2875
# 2   0.100  0.5250
# 3   0.100  0.7625
# 4   0.100  1.0000
# 5   0.225  0.0500
# 6   0.225  0.2875
# 7   0.225  0.5250
# 8   0.225  0.7625
# 9   0.225  1.0000
# 10  0.350  0.0500
# 11  0.350  0.2875
# 12  0.350  0.5250
# 13  0.350  0.7625
# 14  0.350  1.0000
# 15  0.475  0.0500
# 16  0.475  0.2875
# 17  0.475  0.5250
# 18  0.475  0.7625
# 19  0.475  1.0000
# 20  0.600  0.0500
# 21  0.600  0.2875
# 22  0.600  0.5250
# 23  0.600  0.7625
# 24  0.600  1.0000

# %%
beta_min = beta[min_index]
Ewp = E[alpha ==alpha_min][beta[alpha ==alpha_min] ==beta_min]
fep = f_ep[alpha ==alpha_min][beta[alpha ==alpha_min] ==beta_min]

# %%
plt.subplot(1,2,1)
Eep = E[f_ee == f_ee[min_index]]
fep = f_ep[f_ee == f_ee[min_index]]
plt.scatter(fep,Eep)
plt.title('FEP')
plt.subplot(1,2,2)
Eep = E[f_ep == f_ep[min_index]]
fee = f_ee[f_ep == f_ep[min_index]]
plt.scatter(fee,Eep)
plt.title('FEE')
# Out:
# Text(0.5, 1.0, 'FEE')

# %%
plt.subplot(1,2,1)
Ewbf = E[f_bf == f_bf[min_index]]
wbf = w_bf[f_bf == f_bf[min_index]]
plt.scatter(wbf,Ewbf)
plt.title('WBF')
plt.subplot(1,2,2)
Efbf = E[w_bf == w_bf[min_index]]
fbf = f_bf[w_bf == w_bf[min_index]]
plt.scatter(fbf,Efbf)
plt.title('FBF')
# Out:
# Text(0.5, 1.0, 'FBF')
