# %%
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np
#df = pd.read_csv('excited_dmc_one.csv') #628s
df = pd.read_csv('dmc_big.csv')
data = df.to_numpy()
E_exact = -2.175224377034119598311159245194404
w = 1
step = data[:,1]
E = data[:,2]#[data[:,0]==0.001]
E_av = np.mean(E[w:])
E_err = np.std(E[w:])/np.sqrt(len(E[w:]))
pop = data[:,5]
tau = data[:, 0]
step = data[:,1]

# %%
print('Final energy',E_av,'pm',E_err)
# Out:
# Final energy -2.256006285534812 pm 0.00026362191445804614

# %%
df
# Out:
#           tau   step    elocal    weight  elocalvar     weightvar      eref
# 0       0.010      0 -2.100990  0.999250   0.046143  4.517165e-06 -2.174475
# 1       0.010      1 -2.103067  0.998530   0.046976  4.587674e-06 -2.173004
# 2       0.010      2 -2.105876  0.997854   0.048006  4.683877e-06 -2.170855
# 3       0.010      3 -2.107429  0.997216   0.048487  4.728443e-06 -2.168068
# 4       0.010      4 -2.108960  0.996624   0.049098  4.778533e-06 -2.164686
# ...       ...    ...       ...       ...        ...           ...       ...
# 199995  0.001  39995 -2.177684  0.996487   0.070351  6.962710e-08 -1.912405
# 199996  0.001  39996 -2.176942  0.996751   0.070184  6.941383e-08 -1.909150
# 199997  0.001  39997 -2.176488  0.997017   0.069968  6.930459e-08 -1.906163
# 199998  0.001  39998 -2.177349  0.997288   0.070000  6.938993e-08 -1.903447
# 199999  0.001  39999 -2.177606  0.997561   0.070175  6.955988e-08 -1.901006
#
# [200000 rows x 7 columns]

# %%
plt.plot(E, c='b',label = 'MC run')
#plt.plot([0,1000],[E_av,E_av],ls='--',c='r', label='Average')
#plt.plot([200,200],[-2.14,-2.05],ls='--',c='k', label='Equilibration')
plt.grid(True, linestyle='--', alpha=0.5)
plt.xticks(fontsize=12)  # Adjust fontsize for x-axis
plt.yticks(fontsize=12)  # Adjust fontsize for y-axis
plt.xlabel('Monte Carlo Steps', fontsize=16, fontweight='bold')
plt.ylabel(r'Energy (Ha)', fontsize=16, fontweight='bold')
plt.legend()
plt.tight_layout()
plt.show()

# %% [markdown]
# # Final

# %%
w = 5000
E_toav = E[tau==0.0015][w:]
E_average = np.mean(E_toav)
E_errorbar = np.std(E_toav)/np.sqrt(len(E_toav)-w)
print(E_average,'pm',E_errorbar)
# Out:
# -2.171252383010695 pm 5.670849034401119e-05

# %%
plt.plot(step[tau==0.0015], E[tau==0.0015], label='MC run',lw=0.8,c='b')
plt.plot([0,40000],[-2.171252, -2.171252], label = 'Average',c='r',linestyle = '--')
plt.plot([w, w],[-2.21,-2.1], label = 'Equilibration',c='k', linestyle = '--')

plt.grid(True, linestyle='--', alpha=0.5)
plt.xticks(fontsize=12)  # Adjust fontsize for x-axis
plt.yticks(fontsize=12)  # Adjust fontsize for y-axis
plt.ylabel('Energy (Ha)', fontsize=16, fontweight='bold')
plt.xlabel('Monte Carlo Steps', fontsize=16,fontweight='bold')
plt.legend()
plt.tight_layout()
plt.show()

# %%
plt.plot(pop, c='b',label = 'MC run')
#plt.plot([0,1000],[E_av,E_av],ls='--',c='r', label='Average')
#plt.plot([200,200],[-2.14,-2.05],ls='--',c='k', label='Equilibration')
plt.grid(True, linestyle='--', alpha=0.5)
plt.xticks(fontsize=12)  # Adjust fontsize for x-axis
plt.yticks(fontsize=12)  # Adjust fontsize for y-axis
plt.xlabel('Monte Carlo Steps', fontsize=16, fontweight='bold')
plt.ylabel(r'Energy (Ha)', fontsize=16, fontweight='bold')
plt.legend()
plt.tight_layout()
plt.show()

# %%
plt.figure(figsize=(10, 5)) #dpi = 300
plt.subplot(1,2,1)
plt.hist(possample, edgecolor = 'k', alpha = 1)
plt.grid(True, linestyle='--', alpha=0.5)
plt.title('a)', fontsize=16, fontweight='bold',loc='left')
plt.xticks(fontsize=12)  # Adjust fontsize for x-axis
plt.yticks(fontsize=12)  # Adjust fontsize for y-axis
plt.ylim(0,380)
plt.xlabel('X', fontsize=16, fontweight='bold')
plt.ylabel('Counts', fontsize=16, fontweight='bold')


plt.subplot(1,2,2)
plt.hist(posfinal, edgecolor = 'k', alpha = 1)
plt.grid(True, linestyle='--', alpha=0.5)
plt.title('b)', fontsize=16, fontweight='bold',loc='left')
plt.xticks(fontsize=12)  # Adjust fontsize for x-axis
plt.yticks(fontsize=12)  # Adjust fontsize for y-axis


plt.ylim(0,380)
plt.xlabel('X', fontsize=16, fontweight='bold')
plt.tight_layout()
plt.show()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[16], line 3
#       1 plt.figure(figsize=(10, 5)) #dpi = 300
#       2 plt.subplot(1,2,1)
# ----> 3 plt.hist(possample, edgecolor = 'k', alpha = 1)
#       4 plt.grid(True, linestyle='--', alpha=0.5)
#       5 plt.title('a)', fontsize=16, fontweight='bold',loc='left')
#
# NameError: name 'possample' is not defined
